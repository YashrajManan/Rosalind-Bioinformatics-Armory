# %%
from Bio.Seq import Seq

# %%
with open('/mnt/d/Workspace/Python/BIOINFORMATICS_ARMORY/problem1data.txt', 'r') as file:
    my_seq = file.read().strip()

# %%
A = my_seq.count("A")
T = my_seq.count("T")
G = my_seq.count("G")
C = my_seq.count("C")

# %%
print(A,C,G,T)
# Out:
# 238 220 259 229
